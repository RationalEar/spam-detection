# %% [markdown]
# #### Environment Setup

# %%
import os

workspace_dir = '/content/spam-detection'
branch = 'feature/bilstm-training'
current_dir = os.getcwd()
if not os.path.exists(workspace_dir) and current_dir != workspace_dir:
    # !git clone https://github.com/RationalEar/spam-detection.git
    os.chdir(workspace_dir)
    # !git checkout $branch
    # !ls -al
    # !pip install -q transformers==4.48.0 scikit-learn pandas numpy
    # !pip install -q torch --index-url https://download.pytorch.org/whl/cu126
else:
    os.chdir(workspace_dir)
    # !git pull origin $branch
# Out:
# Cloning into 'spam-detection'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 221 (delta 99), reused 177 (delta 61), pack-reused 0 (from 0)
# Receiving objects: 100% (221/221), 2.04 MiB | 21.35 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Branch 'feature/bilstm-training' set up to track remote branch 'feature/bilstm-training' from 'origin'.
# Switched to a new branch 'feature/bilstm-training'
# total 68
# drwxr-xr-x 11 root root 4096 Jun 27 07:33 .
# drwxr-xr-x  1 root root 4096 Jun 27 07:33 ..
# -rw-r--r--  1 root root  584 Jun 27 07:33 docker-compose.yml
# -rw-r--r--  1 root root  879 Jun 27 07:33 Dockerfile
# -rw-r--r--  1 root root   92 Jun 27 07:33 .dockerignore
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 docs
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 explainability
# drwxr-xr-x  8 root root 4096 Jun 27 07:33 .git
# -rw-r--r--  1 root root   38 Jun 27 07:33 .gitignore
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 integrations
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 metrics
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 models
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 preprocess
# -rw-r--r--  1 root root 2536 Jun 27 07:33 requirements.txt
# -rw-r--r--  1 root root  670 Jun 27 07:33 start.sh
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 training
# drwxr-xr-x  2 root root 4096 Jun 27 07:33 utils
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 75.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00

# %%
### If running on Google Colab, mount Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from utils.functions import set_seed
from utils.constants import DATA_PATH, MODEL_SAVE_PATH

set_seed(42)

# %% [markdown]
# #### Load the preprocessed data

# %%
train_df = pd.read_pickle(open(f"{DATA_PATH}/data/processed/train.pkl", "rb"))
val_df = pd.read_pickle(open(f"{DATA_PATH}/data/processed/val.pkl", "rb"))
test_df = pd.read_pickle(open(f"{DATA_PATH}/data/processed/test.pkl", "rb"))
train_df.head()
# Out:
#                                         subject  \
# 0    Personal Finance: Resolutions You Can Keep
# 1      Please help a newbie compile mplayer :-)
# 2  Re: Please help a newbie compile mplayer :-)
# 3  Re: Please help a newbie compile mplayer :-)
# 4  Re: Please help a newbie compile mplayer :-)
#
#                                                 text  label    source  \
# 0  personal finance resolutions you keep motley f...      0  hard_ham
# 1  please help newbie compile mplayer hello i jus...      0  easy_ham
# 2  re please help newbie compile mplayer make sur...      0  easy_ham
# 3  re please help newbie compile mplayer lance wr...      0  easy_ham
# 4  re please help newbie compile mplayer once upo...      0  easy_ham
#
#                                          sender_hash  \
# 0  bb339a04eb35de16f6386c5ca0d57fd88b20916663bd84...
# 1  2f890790e67625bdfd8e3c7cca018bf511c2cbca431554...
# 2  d83f5738686fa88436e12f3710c15b270666e3061ba627...
# 3  2f890790e67625bdfd8e3c7cca018bf511c2cbca431554...
# 4  f9579e33dbc2d625e2ba35d53c611b8c3bd09cca4c7760...
#
#                                        reply_to_hash  \
# 0  3d0448fc6a4d02914e3adf6812ede7310a82838909afac...
# 1  492368811b79453838d5e7e3692f607adee8d7e71ddd2e...
# 2  492368811b79453838d5e7e3692f607adee8d7e71ddd2e...
# 3  492368811b79453838d5e7e3692f607adee8d7e71ddd2e...
# 4  492368811b79453838d5e7e3692f607adee8d7e71ddd2e...
#
#                               date
# 0  Wed, 02 Jan 2002 13:55:00 -0500
# 1  Thu, 31 Jan 2002 22:44:14 -0700
# 2  Fri, 01 Feb 2002 00:53:41 -0600
# 3  Fri, 01 Feb 2002 02:01:44 -0700
# 4  Fri, 01 Feb 2002 10:29:23 +0100

# %%
# Build vocabulary from training data
from utils.functions import build_vocab

word2idx, idx2word = build_vocab(train_df['text'])

# %%
from preprocess.data_loader import load_glove_embeddings

# Load GloVe embeddings
GLOVE_PATH = os.path.join(DATA_PATH, 'data/raw/glove.6B/glove.6B.300d.txt')
embedding_dim = 300
max_len = 200
pretrained_embeddings = load_glove_embeddings(GLOVE_PATH, word2idx, embedding_dim)

# %% [markdown]
# #### Train the BiLSTM model

# %%
from training.trainer import train_model
start_time = pd.Timestamp.now()
model = train_model('bilstm', train_df, val_df, test_df, embedding_dim=embedding_dim, pretrained_embeddings=pretrained_embeddings,
                model_save_path=MODEL_SAVE_PATH, max_len=max_len, evaluate=True)
end_time = pd.Timestamp.now()
# Out:
# Epoch 1/40:
# Train Loss: 0.3078, Train Acc: 0.8656
# Val Loss: 0.1545, Val Acc: 0.9470
# Saved best model to /content/drive/MyDrive/Projects/spam-detection-data/trained-models/best_bilstm_model.pt
# Epoch 2/40:
# Train Loss: 0.1295, Train Acc: 0.9595
# Val Loss: 0.1257, Val Acc: 0.9503
# Saved best model to /content/drive/MyDrive/Projects/spam-detection-data/trained-models/best_bilstm_model.pt
# Epoch 3/40:
# Train Loss: 0.0915, Train Acc: 0.9721
# Val Loss: 0.1026, Val Acc: 0.9636
# Saved best model to /content/drive/MyDrive/Projects/spam-detection-data/trained-models/best_bilstm_model.pt
# Epoch 4/40:
# Train Loss: 0.0648, Train Acc: 0.9775
# Val Loss: 0.1256, Val Acc: 0.9619
# Epoch 5/40:
# Train Loss: 0.0454, Train Acc: 0.9868
# Val Loss: 0.1717, Val Acc: 0.9520
# Epoch 6/40:
# Train Loss: 0.0345, Train Acc: 0.9899
# Val Loss: 0.1732, Val Acc: 0.9536
# Epoch 7/40:
# Train Loss: 0.0259, Train Acc: 0.9926
# Val Loss: 0.1471, Val Acc: 0.9520
# Epoch 8/40:
# Train Loss: 0.0200, Train Acc: 0.9921
# Val Loss: 0.1874, Val Acc: 0.9503
# Epoch 9/40:
# Train Loss: 0.0161, Train Acc: 0.9928
# Val Loss: 0.1546, Val Acc: 0.9652
# Epoch 10/40:
# Train Loss: 0.0139, Train Acc: 0.9965
# Val Loss: 0.1690, Val Acc: 0.9570
# Epoch 11/40:
# Train Loss: 0.0122, Train Acc: 0.9955
# Val Loss: 0.1725, Val Acc: 0.9652
# Epoch 12/40:
# Train Loss: 0.0134, Train Acc: 0.9955
# Val Loss: 0.2504, Val Acc: 0.9487
# Epoch 13/40:
# Train Loss: 0.0144, Train Acc: 0.9961
# Val Loss: 0.3676, Val Acc: 0.9404
# Epoch 14/40:
# Train Loss: 0.0163, Train Acc: 0.9950
# Val Loss: 0.1194, Val Acc: 0.9735
# Epoch 15/40:
# Train Loss: 0.0037, Train Acc: 0.9979
# Val Loss: 0.1953, Val Acc: 0.9570
# Epoch 16/40:
# Train Loss: 0.0048, Train Acc: 0.9973
# Val Loss: 0.2055, Val Acc: 0.9669
# Epoch 17/40:
# Train Loss: 0.0083, Train Acc: 0.9971
# Val Loss: 0.2025, Val Acc: 0.9669
# Epoch 18/40:
# Train Loss: 0.0048, Train Acc: 0.9979
# Val Loss: 0.2388, Val Acc: 0.9685
# Epoch 19/40:
# Train Loss: 0.0131, Train Acc: 0.9965
# Val Loss: 0.2075, Val Acc: 0.9652
# Epoch 20/40:
# Train Loss: 0.0069, Train Acc: 0.9973
# Val Loss: 0.2299, Val Acc: 0.9685
# Epoch 21/40:
# Train Loss: 0.0179, Train Acc: 0.9936
# Val Loss: 0.1478, Val Acc: 0.9768
# Epoch 22/40:
# Train Loss: 0.0050, Train Acc: 0.9973
# Val Loss: 0.1733, Val Acc: 0.9735
# Epoch 23/40:
# Train Loss: 0.0044, Train Acc: 0.9979
# Val Loss: 0.3076, Val Acc: 0.9553
# Epoch 24/40:
# Train Loss: 0.0047, Train Acc: 0.9986
# Val Loss: 0.2380, Val Acc: 0.9619
# Epoch 25/40:
# Train Loss: 0.0022, Train Acc: 0.9988
# Val Loss: 0.2538, Val Acc: 0.9652
# Epoch 26/40:
# Train Loss: 0.0022, Train Acc: 0.9981
# Val Loss: 0.2614, Val Acc: 0.9652
# Epoch 27/40:
# Train Loss: 0.0021, Train Acc: 0.9983
# Val Loss: 0.2720, Val Acc: 0.9652
# Epoch 28/40:
# Train Loss: 0.0022, Train Acc: 0.9988
# Val Loss: 0.2766, Val Acc: 0.9669
# Epoch 29/40:
# Train Loss: 0.0023, Train Acc: 0.9986
# Val Loss: 0.2885, Val Acc: 0.9652
# Epoch 30/40:
# Train Loss: 0.0022, Train Acc: 0.9988
# Val Loss: 0.2984, Val Acc: 0.9652
# Epoch 31/40:
# Train Loss: 0.0027, Train Acc: 0.9988
# Val Loss: 0.2846, Val Acc: 0.9669
# Epoch 32/40:
# Train Loss: 0.0023, Train Acc: 0.9988
# Val Loss: 0.2929, Val Acc: 0.9652
# Epoch 33/40:
# Train Loss: 0.0023, Train Acc: 0.9988
# Val Loss: 0.3009, Val Acc: 0.9652
# Epoch 34/40:
# Train Loss: 0.0023, Train Acc: 0.9986
# Val Loss: 0.2955, Val Acc: 0.9669
# Epoch 35/40:
# Train Loss: 0.0022, Train Acc: 0.9988
# Val Loss: 0.4337, Val Acc: 0.9669
# Epoch 36/40:
# Train Loss: 0.0021, Train Acc: 0.9990
# Val Loss: 0.5893, Val Acc: 0.9669
# Epoch 37/40:
# Train Loss: 0.0023, Train Acc: 0.9988
# Val Loss: 0.5781, Val Acc: 0.9669
# Epoch 38/40:
# Train Loss: 0.0022, Train Acc: 0.9983
# Val Loss: 0.5824, Val Acc: 0.9669
# Epoch 39/40:
# Train Loss: 0.0022, Train Acc: 0.9988
# Val Loss: 0.5970, Val Acc: 0.9652
# Epoch 40/40:
# Train Loss: 0.0021, Train Acc: 0.9988
# Val Loss: 0.5899, Val Acc: 0.9685
# Final model saved to /content/drive/MyDrive/Projects/spam-detection-data/trained-models/spam_bilstm_final.pt
#
# Evaluating on test set:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97       415
#          1.0       0.94      0.95      0.94       191
#
#     accuracy                           0.96       606
#    macro avg       0.96      0.96      0.96       606
# weighted avg       0.96      0.96      0.96       606
#
# Confusion Matrix:
#  [[403  12]
#  [ 10 181]]

# %%
training_time = end_time - start_time
print(f"Training completed in: {training_time}")
# Out:
# Training completed in: 0 days 00:00:46.961394
